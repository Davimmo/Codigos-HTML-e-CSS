# %%
import time
from selenium.webdriver.common.by import By
import undetected_chromedriver as uc
from selenium.webdriver.common.keys import Keys

driver= uc.Chrome()

# %%
driver.get('https://www.youtube.com/watch?v=QvaZLa_FKmY&ab_channel=MichaelKitas')

# %%
canais=driver.find_elements(By.TAG_NAME,'ytd-guide-entry-renderer')
for canal in canais:
    print(canal.text)
# Out:
# Início
# Shorts
# Inscrições
# Biblioteca
# Histórico
# Seus vídeos
# Assistir mais tarde
#
# Vídeos marcados com "Gostei"
# Mostrar mais
#
# Clear Corretora
# Meteoro Brasil
# Splash
# 3Blue1Brown
# 3D Printer Academy
# 5 Alguma Coisa
# A Matemaníaca por Julia Jaccoud
#
# Abimael
# Above The Noise
# Armazém de IA
# aiporT
# Alberto Dell'Isola
# Alex Amorim
# Alimente o Cérebro
# Aline - Minha Casa Minha Vida
# Aline Amorim
# Almanaque SOS
# AlphaPhoenix
# Alura
# Além de Plutão
# Amanda e Fernando
# Amanda Lemette
# Ana Frango Elétrico
# ANDREW HUANG
# Andrezza Santos
# André Young
# Anna-Maria Hefele
# Answer in Progress
# Antológico Books
# Arqueologia pelo Mundo
# Art of Engineering
# Artifexian
# Arvin Ash
# AsapSCIENCE
# Ashley Nichols Art
# AssopraFitas
# AstroTubers
# At Lojart
# atelier kamroyan
# Atila Iamarino
# Augusto Ollivieri
# AURORA
# AustinMcConnell
# Aventuras de Dora Figueiredo
# Aviões e Músicas
# Bagi
# Baixa Qualidade
# Ballon Blum
# Bardoca
# BBC News
# ...

# %%
lista_de_canais=canais[11:18]+canais[19:522]

for elemento in lista_de_canais:
    elemento.find_element(By.CSS_SELECTOR,'[height="24"]').screenshot(f'{elemento.text}.png')
    time.sleep(0.2)

# %%
# Out:
# 510
